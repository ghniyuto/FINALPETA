# %%
import random

def display_instructions():
    print("Welcome to Hangman!")
    print("Instructions:")
    print("1. The computer will choose a random word.")
    print("2. You have to guess the word one letter at a time.")
    print("3. If you guess a wrong letter, you lose a chance.")
    print("4. You have a limited number of chances to guess the word correctly.")
    print("5. If you guess the word before running out of chances, you win!")
    print("6. If you run out of chances, you lose the game.")
    print("Good luck!")
    print("\n")

def choose_random_word():
    words = ["python", "hangman", "programming", "challenge", "developer"]
    return random.choice(words)

def display_word(word, guessed_letters):
    return " ".join([letter if letter in guessed_letters else "_" for letter in word])

def hangman_game():
    display_instructions()

    word_to_guess = choose_random_word()
    guessed_letters = set()
    attempts_left = 6

    print("The word has {} letters.".format(len(word_to_guess)))

    while attempts_left > 0:
        print("\nWord: {}".format(display_word(word_to_guess, guessed_letters)))
        print("Attempts left: {}".format(attempts_left))
        print("Guessed letters: {}".format(" ".join(sorted(guessed_letters))))

        guess = input("Enter a letter: ").lower()

        if len(guess) != 1 or not guess.isalpha():
            print("Please enter a single valid letter.")
            continue

        if guess in guessed_letters:
            print("You already guessed that letter.")
            continue

        guessed_letters.add(guess)

        if guess in word_to_guess:
            print("Good guess!")
            if set(word_to_guess).issubset(guessed_letters):
                print("\nCongratulations! You've guessed the word: {}".format(word_to_guess))
                break
        else:
            print("Wrong guess.")
            attempts_left -= 1

    if attempts_left == 0:
        print("\nYou ran out of attempts. The word was: {}".format(word_to_guess))

if __name__ == "__main__":
    hangman_game()
# Out:
# Welcome to Hangman!
# Instructions:
# 1. The computer will choose a random word.
# 2. You have to guess the word one letter at a time.
# 3. If you guess a wrong letter, you lose a chance.
# 4. You have a limited number of chances to guess the word correctly.
# 5. If you guess the word before running out of chances, you win!
# 6. If you run out of chances, you lose the game.
# Good luck!
#
#
# The word has 6 letters.
#
# Word: _ _ _ _ _ _
# Attempts left: 6
# Guessed letters:
# Wrong guess.
#
# Word: _ _ _ _ _ _
# Attempts left: 5
# Guessed letters: d
# Wrong guess.
#
# Word: _ _ _ _ _ _
# Attempts left: 4
# Guessed letters: d e
# Good guess!
#
# Word: p _ _ _ _ _
# Attempts left: 4
# Guessed letters: d e p
# You already guessed that letter.
#
# Word: p _ _ _ _ _
# Attempts left: 4
# Guessed letters: d e p
# Wrong guess.
#
# Word: p _ _ _ _ _
# Attempts left: 3
# Guessed letters: d e p r
# You already guessed that letter.
#
# Word: p _ _ _ _ _
# Attempts left: 3
# ...
